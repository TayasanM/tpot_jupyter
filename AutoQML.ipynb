# %%
# !pip install git+https://github.com/AutoQML/autoqml.git
# Out:
# ...
#   Cloning https://github.com/AutoQML/autoqml.git to /tmp/pip-req-build-8tfi1ey9
#   Running command git clone --filter=blob:none --quiet https://github.com/AutoQML/autoqml.git /tmp/pip-req-build-8tfi1ey9
# Username for 'https://github.com':

# %%
# !pip install git
# Out:
# ERROR: Could not find a version that satisfies the requirement git (from versions: none)
# ERROR: No matching distribution found for git
