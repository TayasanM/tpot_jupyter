# %%
import autoqml
import pandas as pd
import matplotlib.pyplot as plt

# %%
from autoqml import TabularClassification
print("AutoQML is ready 🚀")
# Out:
# AutoQML is ready 🚀

# %%
import pandas as pd
from datetime import timedelta
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

from autoqml import TabularClassification, AutoQMLFitCommand

# data
X, y = load_iris(return_X_y=True, as_frame=True)  # pandas DataFrame + Series
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=777, stratify=y
)

# optional: keep search space small for a quick test
custom_config = {
    # Example: force a classical algorithm first (fast sanity check)
    "autoqml.search_space.classification.ClassificationChoice__choice": "svc",
    "autoqml.search_space.classification.ClassificationChoice__choice": "qsvc",
    "autoqml.search_space.preprocessing.rescaling.RescalingChoice__choice": "min_max_scaling",
    "autoqml.search_space.preprocessing.dim_reduction.DimReductionChoice__choice": "no-op",
    "autoqml.search_space.classification.quantum.qsvc.QSVC__num_repetitions": 2,
    "autoqml.search_space.classification.quantum.qsvc.QSVC__num_qubits": 2,
    "autoqml.search_space.classification.quantum.qsvc.QSVC__C": 10,
}

autoqml_pipeline = TabularClassification()

cmd = AutoQMLFitCommand(
    X_train,
    y_train,
    timedelta(seconds=120),     # small budget for quick run
    configuration=custom_config # can be {} for full search
)

autoqml_pipeline.fit(cmd)

y_pred = autoqml_pipeline.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/optuna/samplers/_tpe/sampler.py:319: ExperimentalWarning: ``multivariate`` option is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2026-02-18 14:10:28,317] A new study created in memory with name: optuna
# AutoQML optimization started
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:44,063] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#101 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:44,408] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#103 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:10:44,409] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__measurement' in trial#103 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:10:44,410] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__outer_kernel' in trial#103 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:44,600] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#104 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:44,777] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__measurement' in trial#105 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:10:44,778] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__outer_kernel' in trial#105 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:44,918] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#106 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:45,083] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__measurement' in trial#107 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:10:45,083] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__outer_kernel' in trial#107 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:45,544] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__chebyshev_alpha' in trial#110 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:45,693] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#111 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:45,854] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#112 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:46,014] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#113 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:46,178] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#114 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:46,491] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__measurement' in trial#116 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:10:46,492] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__outer_kernel' in trial#116 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:46,824] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__measurement' in trial#118 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:10:46,825] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__outer_kernel' in trial#118 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:47,245] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#121 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:47,379] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__measurement' in trial#122 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:10:47,380] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__outer_kernel' in trial#122 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:47,525] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__chebyshev_alpha' in trial#123 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:47,665] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__chebyshev_alpha' in trial#124 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:10:48,386] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#129 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:10:48,387] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__chebyshev_alpha' in trial#129 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# ...
# [W 2026-02-18 14:12:21,934] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__measurement' in trial#602 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:12:21,936] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__outer_kernel' in trial#602 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:12:22,352] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__chebyshev_alpha' in trial#603 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:12:22,749] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#604 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:12:23,152] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__measurement' in trial#605 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:12:23,154] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__outer_kernel' in trial#605 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:12:23,571] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#606 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:12:23,966] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__chebyshev_alpha' in trial#607 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:12:23,969] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__num_chebyshev' in trial#607 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:12:24,386] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#608 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:12:24,389] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__chebyshev_alpha' in trial#608 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:12:25,189] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#610 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:12:25,591] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#611 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:12:25,594] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__measurement' in trial#611 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:12:25,595] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__outer_kernel' in trial#611 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:12:26,398] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#613 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:12:27,259] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__chebyshev_alpha' in trial#615 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:12:27,262] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__num_chebyshev' in trial#615 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:12:27,263] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__measurement' in trial#615 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:12:27,265] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__outer_kernel' in trial#615 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:12:27,672] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#616 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:12:28,103] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#617 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:12:28,521] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__measurement' in trial#618 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2026-02-18 14:12:28,523] The parameter 'autoqml.search_space.classification.quantum.qsvc.QSVC__outer_kernel' in trial#618 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [W 2026-02-18 14:12:28,920] The parameter 'autoqml.search_space.preprocessing.encoding.one_hot.OneHotEncoder__min_frequency' in trial#619 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# <IPython.core.display.HTML object>
# Accuracy: 0.9210526315789473

# %%
print(autoqml_pipeline)
# Out:
# <autoqml.automl.TabularClassification object at 0x7a3fdd42cd90>

# %%
print(autoqml_pipeline.pipeline)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /tmp/ipykernel_14897/2749393716.py:1
# ----> 1 print(autoqml_pipeline.pipeline)
#
# AttributeError: 'TabularClassification' object has no attribute 'pipeline'

# %%
from datetime import timedelta
from autoqml import TabularClassification, AutoQMLFitCommand
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# Load data
X, y = load_iris(return_X_y=True, as_frame=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=777, stratify=y
)

# Full AutoQML search (classical + quantum)
automl = TabularClassification()

cmd = AutoQMLFitCommand(
    X_train,
    y_train,
    timedelta(seconds=180),   # give it more time
    configuration={}          # empty = full search space
)

automl.fit(cmd)

y_pred = automl.predict(X_test)

from sklearn.metrics import accuracy_score
print("Final Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/optuna/samplers/_tpe/sampler.py:319: ExperimentalWarning: ``multivariate`` option is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2026-02-18 13:38:25,439] A new study created in memory with name: optuna
# AutoQML optimization started
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Seed set to 777
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name    | Type     | Params | Mode
# ---------------------------------------------
# 0 | encoder | _Encoder | 50     | train
# 1 | decoder | _Decoder | 44     | train
# ---------------------------------------------
# 94        Trainable params
# 0         Non-trainable params
# 94        Total params
# 0.000     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/loggers/tensorboard.py:191: Could not log computational graph to TensorBoard: The `model.example_input_array` attribute is not set or `input_array` was not given.
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]
# Training: |                                               | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:475: Your `test_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Seed set to 777
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name    | Type     | Params | Mode
# ---------------------------------------------
# 0 | encoder | _Encoder | 45     | train
# 1 | decoder | _Decoder | 40     | train
# ---------------------------------------------
# 85        Trainable params
# 0         Non-trainable params
# 85        Total params
# 0.000     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/loggers/tensorboard.py:191: Could not log computational graph to TensorBoard: The `model.example_input_array` attribute is not set or `input_array` was not given.
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]
# Training: |                                               | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=37` reached.
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:475: Your `test_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# self.quantum_kernel <squlearn.kernel.matrix.fidelity_kernel.FidelityKernel object at 0x7a4123b29c90>
# kwargs {}
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Seed set to 777
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name    | Type     | Params | Mode
# ---------------------------------------------
# 0 | encoder | _Encoder | 35     | train
# 1 | decoder | _Decoder | 32     | train
# ---------------------------------------------
# 67        Trainable params
# 0         Non-trainable params
# 67        Total params
# 0.000     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/loggers/tensorboard.py:191: Could not log computational graph to TensorBoard: The `model.example_input_array` attribute is not set or `input_array` was not given.
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]
# Training: |                                               | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=49` reached.
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:475: Your `test_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Seed set to 777
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name    | Type     | Params | Mode
# ---------------------------------------------
# 0 | encoder | _Encoder | 35     | train
# 1 | decoder | _Decoder | 32     | train
# ---------------------------------------------
# 67        Trainable params
# 0         Non-trainable params
# 67        Total params
# 0.000     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/loggers/tensorboard.py:191: Could not log computational graph to TensorBoard: The `model.example_input_array` attribute is not set or `input_array` was not given.
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]
# Training: |                                               | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=41` reached.
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:475: Your `test_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Seed set to 777
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name    | Type     | Params | Mode
# ---------------------------------------------
# 0 | encoder | _Encoder | 30     | train
# 1 | decoder | _Decoder | 28     | train
# ---------------------------------------------
# 58        Trainable params
# 0         Non-trainable params
# 58        Total params
# 0.000     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/loggers/tensorboard.py:191: Could not log computational graph to TensorBoard: The `model.example_input_array` attribute is not set or `input_array` was not given.
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]
# Training: |                                               | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=20` reached.
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:475: Your `test_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Seed set to 777
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name    | Type     | Params | Mode
# ---------------------------------------------
# 0 | encoder | _Encoder | 30     | train
# 1 | decoder | _Decoder | 28     | train
# ---------------------------------------------
# 58        Trainable params
# 0         Non-trainable params
# 58        Total params
# 0.000     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/loggers/tensorboard.py:191: Could not log computational graph to TensorBoard: The `model.example_input_array` attribute is not set or `input_array` was not given.
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]
# Training: |                                               | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=47` reached.
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:475: Your `test_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Seed set to 777
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name    | Type     | Params | Mode
# ---------------------------------------------
# 0 | encoder | _Encoder | 35     | train
# 1 | decoder | _Decoder | 32     | train
# ---------------------------------------------
# 67        Trainable params
# 0         Non-trainable params
# 67        Total params
# 0.000     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/loggers/tensorboard.py:191: Could not log computational graph to TensorBoard: The `model.example_input_array` attribute is not set or `input_array` was not given.
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]
# Training: |                                               | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=27` reached.
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:475: Your `test_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Seed set to 777
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name    | Type     | Params | Mode
# ---------------------------------------------
# 0 | encoder | _Encoder | 25     | train
# 1 | decoder | _Decoder | 24     | train
# ---------------------------------------------
# 49        Trainable params
# 0         Non-trainable params
# 49        Total params
# 0.000     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/loggers/tensorboard.py:191: Could not log computational graph to TensorBoard: The `model.example_input_array` attribute is not set or `input_array` was not given.
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]
# Training: |                                               | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=21` reached.
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:475: Your `test_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Seed set to 777
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name    | Type     | Params | Mode
# ---------------------------------------------
# 0 | encoder | _Encoder | 50     | train
# 1 | decoder | _Decoder | 44     | train
# ---------------------------------------------
# 94        Trainable params
# 0         Non-trainable params
# 94        Total params
# 0.000     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/loggers/tensorboard.py:191: Could not log computational graph to TensorBoard: The `model.example_input_array` attribute is not set or `input_array` was not given.
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]
# Training: |                                               | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=27` reached.
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:475: Your `test_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# <IPython.core.display.HTML object>                       | 0/27 [00:00<?, ?it/s]
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# ...
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]
# Training: |                                               | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=33` reached.
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:475: Your `test_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# self.quantum_kernel <squlearn.kernel.matrix.fidelity_kernel.FidelityKernel object at 0x7a41707d1c30>
# kwargs {}
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Seed set to 777
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name    | Type     | Params | Mode
# ---------------------------------------------
# 0 | encoder | _Encoder | 50     | train
# 1 | decoder | _Decoder | 44     | train
# ---------------------------------------------
# 94        Trainable params
# 0         Non-trainable params
# 94        Total params
# 0.000     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/loggers/tensorboard.py:191: Could not log computational graph to TensorBoard: The `model.example_input_array` attribute is not set or `input_array` was not given.
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]
# Training: |                                               | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=43` reached.
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:475: Your `test_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# fit:   0%|                                               | 0/71 [00:00<?, ?it/s]:task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Seed set to 777
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name    | Type     | Params | Mode
# ---------------------------------------------
# 0 | encoder | _Encoder | 30     | train
# 1 | decoder | _Decoder | 28     | train
# ---------------------------------------------
# 58        Trainable params
# 0         Non-trainable params
# 58        Total params
# 0.000     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/loggers/tensorboard.py:191: Could not log computational graph to TensorBoard: The `model.example_input_array` attribute is not set or `input_array` was not given.
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]
# Training: |                                               | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=44` reached.
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:475: Your `test_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# fit:   0%|                                               | 0/40 [00:00<?, ?it/s]:task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# Final Accuracy: 0.9210526315789473

# %%
print(automl)
# Out:
# <autoqml.automl.TabularClassification object at 0x7a3fdd3a5cc0>

# %%
dir(automl)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_construct_search_space',
#  '_get_metric',
#  '_validate_input_parameters',
#  'fit',
#  'path',
#  'pipeline_',
#  'predict',
#  'seed']

# %%
for attr in dir(automl):
    if "pipeline" in attr.lower():
        print(attr)
# Out:
# pipeline_

# %%
print(automl.pipeline_)
# Out:
# TunablePipeline(steps=[('encoding',
#                         EncoderChoice(estimator=OneHotEncoder(min_frequency=0.02))),
#                        ('rescaling', RescalingChoice(estimator=NoOp())),
#                        ('dim_reduction',
#                         DimReductionChoice(estimator=UMAP(n_components=0.8919233550156721))),
#                        ('rescalingQC',
#                         RescalingChoiceQML(estimator=MinMaxScalingForQuantumKernel(range_factor=0.8061939890460857))),
#                        ('classification',
#                         ClassificationChoice(estimator=GaussianProcessClassifier(multi_class='one_vs_one')))])

# %%
custom_config = {
    "autoqml.search_space.classification.ClassificationChoice__choice": "qsvc"
}

automl_quantum = TabularClassification()

cmd_q = AutoQMLFitCommand(
    X_train,
    y_train,
    timedelta(seconds=180),
    configuration=custom_config
)

automl_quantum.fit(cmd_q)

y_pred_q = automl_quantum.predict(X_test)

print("Quantum Accuracy:", accuracy_score(y_test, y_pred_q))
# Out:
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/optuna/samplers/_tpe/sampler.py:319: ExperimentalWarning: ``multivariate`` option is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2026-02-18 15:33:49,880] A new study created in memory with name: optuna
# AutoQML optimization started
# <IPython.core.display.HTML object>
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# :task_name:bundle_reservation_check_func
# :actor_name:ImplicitFunc
# :actor_name:func
# Seed set to 777
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name    | Type     | Params | Mode
# ---------------------------------------------
# 0 | encoder | _Encoder | 50     | train
# 1 | decoder | _Decoder | 44     | train
# ---------------------------------------------
# 94        Trainable params
# 0         Non-trainable params
# 94        Total params
# 0.000     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/loggers/tensorboard.py:191: Could not log computational graph to TensorBoard: The `model.example_input_array` attribute is not set or `input_array` was not given.
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Training: |                                               | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# ...
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=46` reached.
# /home/michael/tpot_jupyter/miniconda3/envs/autoqml_env/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:475: Your `test_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# Testing: |                                                | 0/? [00:00<?, ?it/s]
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# Quantum Accuracy: 0.9210526315789473

# %%
print("Auto (mixed) accuracy:", accuracy_score(y_test, y_pred))
print("Forced quantum accuracy:", accuracy_score(y_test, y_pred_q))
# Out:
# Auto (mixed) accuracy: 0.9210526315789473
# Forced quantum accuracy: 0.9210526315789473

# %%
print(automl_quantum.pipeline_)
# Out:
# TunablePipeline(steps=[('encoding',
#                         EncoderChoice(estimator=OneHotEncoder(min_frequency=0.2))),
#                        ('rescaling', RescalingChoice(estimator=NoOp())),
#                        ('dim_reduction',
#                         DimReductionChoice(estimator=UMAP(n_components=0.32670088176826007))),
#                        ('rescalingQC',
#                         RescalingChoiceQML(estimator=MinMaxScalingForQuantumKernel(range_factor=0.23274412927905685))),
#                        ('classification',
#                         ClassificationChoice(estimator=QSVC(C=28293.745384694037,
#                                                             chebyshev_alpha=None,
#                                                             encoding_circuit='yz_cx_encoding_circuit',
#                                                             measurement=None,
#                                                             num_qubits=1,
#                                                             num_repetitions=2,
#                                                             outer_kernel=None,
#                                                             parameter_seed=2105845428,
#                                                             quantum_kernel='fidelity_quantum_kernel',
#                                                             trial_id='')))])
